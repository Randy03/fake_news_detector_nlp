# %%
import pandas as pd
from gensim.utils import simple_preprocess
from gensim import corpora
import matplotlib.pyplot as plt
import seaborn as sns
from gensim import models

# %%
data = pd.read_csv('fake_or_real_cleaned.csv')

# %%
data.text = data.text.str.replace("[^A-Za-z ]", " ")
# Out:
# C:\Users\remoteUser\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
data.text
# Out:
# 0       Daniel Greenfield  a Shillman Journalism Fello...
# 1       Google Pinterest Digg Linkedin Reddit Stumbleu...
# 2       U S  Secretary of State John F  Kerry said Mon...
# 3         Kaydee King   KaydeeKing  November         T...
# 4       It s primary day in New York and front runners...
#                               ...
# 6301    The State Department told the Republican Natio...
# 6302    The  P  in PBS Should Stand for  Plutocratic  ...
# 6303     Anti Trump Protesters Are Tools of the Oligar...
# 6304    ADDIS ABABA  Ethiopia  President Obama convene...
# 6305    Jeb Bush Is Suddenly Attacking Trump  Here s W...
# Name: text, Length: 6306, dtype: object

# %%
texts = data.text.apply(simple_preprocess)

# %%
dictionary = corpora.Dictionary(texts)
dictionary.filter_extremes(no_below=5, no_above=0.5)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
tfidf = models.TfidfModel(corpus)
corpus_tfidf = tfidf[corpus]

# %%
n_topics = 15

# Build an LSI model
lsi_model = models.LsiModel(corpus_tfidf,
                            id2word=dictionary,
                            num_topics=n_topics)

# %%
lsi_model.print_topics()
# Out:
# [(0,
#   '0.284*"trump" + 0.203*"clinton" + 0.121*"her" + 0.120*"sanders" + 0.118*"she" + 0.091*"cruz" + 0.088*"campaign" + 0.087*"hillary" + 0.087*"obama" + 0.083*"party"'),
#  (1,
#   '-0.398*"dismantling" + -0.308*"obamacare" + -0.269*"killing" + -0.266*"pushing" + -0.261*"tax" + -0.254*"reform" + -0.235*"rules" + -0.220*"list" + -0.204*"administration" + 0.202*"trump"'),
#  (2,
#   '-0.280*"trump" + -0.242*"dismantling" + -0.202*"cruz" + -0.178*"obamacare" + -0.172*"sanders" + -0.157*"pushing" + -0.154*"reform" + -0.150*"tax" + -0.147*"rules" + -0.145*"killing"'),
#  (3,
#   '-0.393*"clinton" + -0.309*"fbi" + -0.240*"emails" + -0.221*"comey" + -0.218*"her" + 0.182*"cruz" + -0.175*"she" + -0.173*"sanders" + -0.167*"investigation" + -0.162*"hillary"'),
#  (4,
#   '0.615*"sanders" + -0.384*"trump" + -0.176*"fbi" + 0.150*"clinton" + 0.149*"iran" + -0.147*"comey" + 0.125*"delegates" + 0.119*"bernie" + 0.116*"democratic" + -0.092*"investigation"'),
#  (5,
#   '-0.334*"trump" + -0.281*"russia" + -0.216*"russian" + -0.201*"syria" + -0.129*"putin" + -0.128*"isis" + 0.126*"court" + -0.125*"clinton" + -0.118*"syrian" + 0.116*"police"'),
#  (6,
#   '0.383*"iran" + 0.189*"nuclear" + 0.185*"fbi" + 0.181*"deal" + 0.174*"cruz" + 0.163*"rubio" + -0.157*"sanders" + 0.156*"comey" + -0.148*"trump" + 0.140*"netanyahu"'),
#  (7,
#   '-0.334*"trump" + 0.294*"cruz" + -0.269*"iran" + 0.267*"rubio" + 0.170*"bush" + -0.165*"nuclear" + 0.147*"police" + 0.131*"isis" + -0.127*"deal" + 0.119*"fbi"'),
#  (8,
#   '-0.525*"startups" + -0.448*"verdict" + -0.388*"sweeping" + -0.376*"tech" + -0.308*"consequences" + 0.112*"police" + 0.089*"iran" + -0.082*"could" + -0.071*"percent" + -0.070*"russia"'),
#  (9,
#   '0.287*"police" + 0.244*"iran" + 0.200*"startups" + -0.193*"percent" + 0.174*"verdict" + -0.170*"russia" + 0.146*"sweeping" + 0.142*"tech" + -0.129*"russian" + 0.123*"officers"'),
#  (10,
#   '0.252*"rubio" + 0.242*"bush" + -0.195*"police" + -0.177*"trump" + -0.159*"ryan" + 0.138*"she" + -0.134*"boehner" + 0.131*"her" + -0.117*"house" + -0.115*"delegates"'),
#  (11,
#   '0.250*"cruz" + 0.246*"delegates" + -0.232*"she" + -0.220*"her" + -0.181*"bush" + 0.181*"fbi" + 0.162*"comey" + 0.155*"sanders" + -0.143*"clinton" + -0.127*"isis"'),
#  (12,
#   '-0.346*"percent" + 0.255*"cruz" + -0.216*"quotes" + -0.207*"photos" + -0.182*"poll" + -0.171*"police" + 0.170*"delegates" + -0.156*"numbers" + -0.147*"voters" + -0.143*"election"'),
#  (13,
#   '0.473*"quotes" + 0.451*"photos" + 0.268*"numbers" + 0.233*"center" + 0.211*"election" + 0.211*"candidates" + -0.205*"percent" + 0.127*"court" + 0.118*"marriage" + 0.088*"two"'),
#  (14,
#   '-0.299*"russia" + -0.230*"russian" + -0.218*"police" + 0.214*"isis" + -0.201*"court" + -0.163*"marriage" + -0.157*"putin" + 0.152*"mosul" + 0.130*"iraqi" + 0.108*"your"')]

# %%
n_words = 10

topic_words = pd.DataFrame({})

for i, topic in enumerate(lsi_model.get_topics()):
    top_feature_ids = topic.argsort()[-n_words:][::-1]
    feature_values = topic[top_feature_ids]
    words = [dictionary[id] for id in top_feature_ids]
    topic_df = pd.DataFrame({'value': feature_values, 'word': words, 'topic': i})
    topic_words = pd.concat([topic_words, topic_df], ignore_index=True)

topic_words.head()
# Out:
#       value     word  topic
# 0  0.284435    trump      0
# 1  0.202738  clinton      0
# 2  0.120725      her      0
# 3  0.120418  sanders      0
# 4  0.117576      she      0

# %%
g = sns.FacetGrid(topic_words, col="topic", col_wrap=3, sharey=False)
g.map(plt.barh, "word", "value")
